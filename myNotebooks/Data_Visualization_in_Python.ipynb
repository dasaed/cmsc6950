# %% [markdown]
# # Visualizing Data in Python
# ### Using matplotlib

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

fig, ax_lst = plt.subplots(2,3) # a figure with a 2x3 grid of axes
fig.suptitle("A figure with a 2x3 Grid of Axes")
# Out:
# Text(0.5, 0.98, 'A figure with a 2x3 Grid of Axes')

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig2, (ax1,ax2) = plt.subplots(2,2)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

fig = plt.figure() # create a new figure
axis1 = fig.add_subplot(1,2,1) # just left 
axis2 = fig.add_subplot(2,2,2) # top right
axis3 = fig.add_subplot(2,2,4) # bottom right

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

axis = plt.axis([2,6,4,8])

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig, ax_list = plt.subplots(2,2)

ax_list[0,0].set_xlim(0, 4)
ax_list[0,1].set_ylim(2, 6)
ax_list[1,0].set_xlabel("Label for x axis 10")
ax_list[1,1].set_ylabel("Label for y axis 11")

plt.tight_layout() # adjusting the location of axes

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

fig, ax_lst = plt.subplots(2,2)  # a figure with a 2x2 grid of Axes

# Graph top-left
ax_lst[0,0].plot([3, 2, 3, 1], "r") # plots the values on the list against their indices
ax_lst[0,0].bar([0,2,3],[2.5,4,5]) # val of bar on x vs value on y

# Graph bottom-right
ax_lst[1,1].arrow(0,0,0.5,0.2) # Coordinates for a line segment = (x-starting,y-starting,x-ending,y-ending)
ax_lst[1,1].axhline(0.45)

# Graph top-right
ax_lst[0,1].plot([1, 2, 3, 4], [1, 8, 27, 64], "g", marker='o', linestyle='dashed') # basic plot

# Graph bottom-left
ax_lst[1,0].barh([1,2,5],[0.5,1,2]) # bar, but horizontal = barh


plt.tight_layout() # adjusting the location of axes

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 5, 0.1);
y = np.sin(x)
plt.plot(x, y)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import scipy.stats

np.random.seed(0)

# example data

x = 100 + 15 * np.random.randn(500)

fig, ax = plt.subplots()

# the histogram of the data
#n, bins, patches = ax.hist(x, 20, normed=1) # the normed option is depricated now
n, bins, patches = ax.hist(x, 20, density=1)

# add a 'best fit' line
#y = mlab.normpdf(bins, 100, 15) # this is depricated as well
y = scipy.stats.norm.pdf(bins, 100, 15)
ax.plot(bins, y, '--')

# %%
# %matplotlib inline
"""
This example showcases the most basic fill plot a user can do with matplotlib.
"""
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 1, 500)
y = np.sin(4 * np.pi * x) * np.exp(-5 * x)

fig, ax = plt.subplots()

ax.fill(x, y, zorder=10)
ax.grid(True, zorder=5)
plt.show()

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(0, 10, 500)
dashes = [10, 5, 100, 5]  # 10 points on, 5 off, 100 on, 5 off

fig, ax = plt.subplots()
line1, = ax.plot(x, np.sin(x), '--', linewidth=2, label='Dashes set retroactively')
line1.set_dashes(dashes)

line2, = ax.plot(x, -1 * np.sin(x), dashes=[10, 10, 10, 10], label='Dashes set proactively')

ax.legend(loc='lower right')
plt.show()

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(0, 10, 500)
dashes = [10, 5, 100, 5]  # 10 points on, 5 off, 100 on, 5 off

fig, ax = plt.subplots()
line1, = ax.plot(x, np.sin(x), '--', linewidth=2, label='Dashes set retroactively')
line1.set_dashes(dashes)

line2, = ax.plot(x, -1 * np.sin(x), dashes=[10, 10, 10, 10], label='Dashes set proactively')

ax.legend(loc='lower right')
plt.show()


plt.savefig('foo.png')

plt.savefig('foo.png', transparent=True) #Save transparent figures

plt.show()
